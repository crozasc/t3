# %%
#Cargar el conjunto de datos procesado de la tarea 2 como punto de partida.
import requests
url="https://raw.githubusercontent.com/crozasc/t2/main/New.csv"
target_csv_path="forbes_2022_billionaires.csv"

response= requests.get(url)

response.raise_for_status()
with open(target_csv_path,"wb") as f:
    f.write(response.content)
print("CSV descargado correctamente")
# Out:
# CSV descargado correctamente

# %%
# Cargar librerias.
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt
# Utilizar los métodos pandas.read_xxx() y pandas.to_xxx() para leer y guardar los datos.
df = pd.read_csv("forbes_2022_billionaires.csv")
df.head()
# Out:
#    rank                personName  age   finalWorth               category  \
# 0     1                 Elon Musk   50  186918690.0             Automotive
# 1     2                Jeff Bezos   58  145950210.0             Technology
# 2     3  Bernard Arnault & family   73  134854580.0       Fashion & Retail
# 3     4                Bill Gates   66  110102790.0             Technology
# 4     5            Warren Buffett   91  100714180.0  Finance & Investments
#
#                source        country                      organization  \
# 0       Tesla, SpaceX  United States                             Tesla
# 1              Amazon  United States                            Amazon
# 2                LVMH         France  LVMH Moët Hennessy Louis Vuitton
# 3           Microsoft  United States   Bill & Melinda Gates Foundation
# 4  Berkshire Hathaway  United States                Berkshire Hathaway
#
#    selfMade             title  \
# 0      True               CEO
# 1      True      Entrepreneur
# 2     False  Chairman and CEO
# 3      True         Cofounder
# 4      True               CEO
#
#                                                  bio hasSibling Worth-binned  \
# 0  Elon Musk is working to revolutionize transpor...      False         Alto
# 1  Jeff Bezos founded e-commerce giant Amazon in ...      False         Alto
# 2  Bernard Arnault oversees the LVMH empire of so...      False         Alto
# 3  Bill Gates turned his fortune from software fi...      False        Medio
# 4  Known as the "Oracle of Omaha," Warren Buffett...      False        Medio
#
#    Female  Male
# 0       0     1
# 1       0     1
# 2       0     1
# 3       0     1
# 4       0     1

# %%
#Grafico 1
mpl.style.use('dark_background')
df.groupby(['category']).size().plot(
    kind = "bar",
    figsize=(13, 10),
    alpha=0.9,
    color=['coral', 'darkslateblue', 'mediumseagreen']
    )
plt.title('Millonaires categories')
plt.ylabel('Number of millonaires')
plt.xlabel('Categories')
plt.savefig('1.png')
plt.show()

# %%
#Grafico 2
mpl.style.use('tableau-colorblind10')
df.groupby(['selfMade']).size().plot(
    kind='pie',
    figsize=(5,6),
    autopct='%1.1f%%', 
    colors=['lightcoral','purple'],
    pctdistance=1.12, 
    labels=None
    )
plt.ylabel('')
plt.title('Percentage of millionaires selfmade')
plt.axis('equal') # Establece el gráfico para que parezca un círculo.
plt.legend(["False","True"],loc='upper left') 
plt.rcParams.update({'font.size': 11})
plt.savefig('2.png')
plt.show()

# %%
#Grafico 3
mpl.style.use('seaborn-white')
x = df['age']      # año en el eje x
y = df['finalWorth']     # total en el eje y
ajuste = np.polyfit(x, y, deg=1)
df.plot(
    kind='scatter', 
    x='age', 
    y='finalWorth', 
    figsize=(10, 6), 
    color='black'
    )
plt.title('Age vs money')
plt.xlabel('Age')
plt.ylabel('Money')
plt.plot(x, ajuste[0] * x + ajuste[1], color='red')
plt.savefig('3.png')
plt.show()

# %%
#Grafico 4
